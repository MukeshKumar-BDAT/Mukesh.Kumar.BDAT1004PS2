# %% [markdown]
# ## Problem Set 2

# %% [markdown]
# ## Question 1
#
# Consider the following Python module:
# a = 0
# def b():
#  global a
#  a = c(a)
# def c(a):
#  return a + 2
# After importing the module into the interpreter, you execute:
#
# b()
#
# b()
#
# b()
#
#  a
#
# ?
# What value is displayed when the last expression (a) is evaluated? Explain your
# answer by indicating what happens in every executed statement.

# %%
a = 0
def b():
    global a
    a = c(a)
    
def c(a):
    return a + 2 

b()
b()
b()
a

# the value of a is increased eveytime c() is called, and c() is called everytime b() is called.As we called b() 3 times it is 6 so Value of a is 6
# Out:
# 6

# %% [markdown]
# ## Question 2
#
# Function fileLength(), given to you, takes the name of a file as input and returns
# the length of the file:
# >>> fileLength('midterm.py')
# 284
# >>> fileLength('idterm.py')
# Traceback (most recent call last):
# File "<pyshell#34>", line 1, in <module>
#  fileLength('idterm.py')
# File "/Users/me/midterm.py", line 3, in fileLength
#  infile = open(filename)
# FileNotFoundError: [Errno 2] No such file or directory:
# 'idterm.py'
# As shown above, if the file cannot be found by the interpreter or if it cannot be read
# as a text file, an exception will be raised. Modify function fileLength() so that a
# friendly message is printed instead:
# >>> fileLength('midterm.py')
# 358
# >>> fileLength('idterm.py')
# File idterm.py not found.

# %%
def file_length(file_name):
    try:
        #Read File
        file = open(file_name)
        contents = file.read()
        file.close()
        print(len(contents))#if file is found
    except:
        print("File " + file_name + " not found.")#if file not found
    
file_length("idterm.py")#file name being parsed
# Out:
# File idterm.py not found.

# %% [markdown]
# ## Question 3
#
# Write a class named Marsupial that can be used as shown below:
# >>> m = Marsupial()
# >>> m.put_in_pouch('doll')
# >>> m.put_in_pouch('firetruck')
# >>> m.put_in_pouch('kitten')
# >>> m.pouch_contents()
# ['doll', 'firetruck', 'kitten']
#
# Now write a class named Kangaroo as a subclass of Marsupial that inherits all the
# attributes of Marsupial and also:
# a. extends the Marsupial __init__ constructor to take, as input, the
# coordinates x and y of the Kangaroo object,
# b. supports method jump that takes number values dx and dy as input and
# moves the kangaroo by dx units along the x-axis and by dy units along the yaxis, and
# c. overloads the __str__ operator so it behaves as shown below.
# >>> k = Kangaroo(0,0)
# >>> print(k)
# I am a Kangaroo located at coordinates (0,0)
# >>> k.put_in_pouch('doll')
# >>> k.put_in_pouch('firetruck')
# >>> k.put_in_pouch('kitten')
# >>> k.pouch_contents()
# ['doll', 'firetruck', 'kitten']
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> k.jump(1,0)
# >>> print(k)
#
# I am a Kangaroo located at coordinates (3,0)

# %%
class Marsupial:
    l = []
    def __init__(self, x, y):
        self.x = x
        self.y = y
    
    def put_in_pouch(self, s):
        self.l.append(s)
        
    def pouch_contents(self):
        print(self.l)
        
class Kangaroo(Marsupial):#creating subcalss of Marsupial
    def jump(self, dx, dy):
        self.x += dx
        self.y += dy
        
    def __str__(self):#overloading __str__()
        return "I am a Kangaroo located at coordinates ({},{})".format(self.x, self.y)
    
    
    
k = Kangaroo(0,0)
print(k)
k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
k.pouch_contents()
k.jump(1,0)
k.jump(1,0)
k.jump(1,0)
print(k)
# Out:
# I am a Kangaroo located at coordinates (0,0)
# ['doll', 'firetruck', 'kitten']
# I am a Kangaroo located at coordinates (3,0)

# %% [markdown]
# ## Question 4
#
# Write function collatz() that takes a positive integer x as input and prints the
# Collatz sequence starting at x. A Collatz sequence is obtained by repeatedly applying
# this rule to the previous number x in the sequence:
# x = {
# 𝑥/2 𝑖𝑓 𝑥 𝑖𝑠 𝑒𝑣𝑒𝑛
# 3𝑥 + 1 𝑖𝑓 𝑥 𝑖𝑠 𝑜𝑑𝑑
# Your function should stop when the sequence gets to number 1. Your
# implementation must be recursive, without any loops.
#
#
# collatz(1)
#
# 1
#
# collatz(10)
#
# 10
#
# 5
#
# 16
#
# 8
#
# 4
#
# 2
#
# 1

# %% [markdown]
# def collatz(x):#defining recursive function collatz
#     print(x)
#     while x != 1:
#         if (x & 1): # Fancy way of asking if the number is odd (Lil-bit faster than x%2 == 1)
#             x = 3 * x + 1
#         else:
#             x = x // 2
#         print(x)
#
# n = int(input("Enter a number : "))
# collatz(n)#calling function collatz

# %% [markdown]
# ## Question 5
#
# Write a recursive method binary() that takes a non-negative
# integer n and prints the binary representation of integer n.
# binary(0)
#
# 0
#
# binary(1)
#
# 1
#
# binary(3)
#
# 11
#
# binary(9)
#
# 1001

# %%
l = []
def Binary_helper(n):#function to return binary values
    if (n == 0):
        return
    l.append(str(n % 2))
    Binary_helper(n//2)

def Binary(n):#function to collect values and then print them
    Binary_helper(n)
    s = ''.join(map(str, l[::-1]))
    print(s)

n = int(input("Enter a number : "))
Binary(n)
# Out:
# Enter a number : 8
# 1000

# %% [markdown]
# ## Question 6
#
# Implement a class named HeadingParser that can be used to parse an HTML
# document, and retrieve and print all the headings in the document. You should
# implement your class as a subclass of HTMLParser, defined in Standard Library
# module html.parser. When fed a string containing HTML code, your class should
# print the headings, one per line and in the order in which they appear in the
# document. Each heading should be indented as follows: an h1 heading should have indentation 0, and h2 heading should have indentation 1, etc. Test your
# implementation using w3c.html.
#
# infile = open('w3c.html')
#
# content = infile.read()
#
# infile.close()
#
# hp = HeadingParser()
#
# hp.feed(content)
#
# W3C Mission
#
# Principles

# %%
from html.parser import HTMLParser

class HeadingParser(HTMLParser):
    (h1,h2,h3,h4,h5,h6) = (False, False,False,False,False,False)
    
    def handle_starttag(self, tag, attrs):
        if tag == 'h1':
            self.h1 = True
        if tag == 'h2':
            self.h2 = True
        if tag == 'h3':
            self.h3 = True
        if tag == 'h4':
            self.h4 = True
        if tag == 'h5':
            self.h5 = True
        if tag == 'h6':
            self.h6 = True
            

    def handle_endtag(self, tag):
        if tag == 'h1':
            self.h1 = False
        if tag == 'h2':
            self.h2 = False
        if tag == 'h3':
            self.h3 = False
        if tag == 'h4':
            self.h4 = False
        if tag == 'h5':
            self.h5 = False
        if tag == 'h6':
            self.h6 = False
            

    def handle_data(self, data):
        if self.h1:
            print(data)
        elif self.h2:
            print("    {}".format(data))
        elif self.h3:
            print("        {}".format(data))
        elif self.h4:
            print("            {}".format(data))
        elif self.h5:
            print("                {}".format(data))
        elif self.h6:
            print("                    {}".format(data))
        
        
infile = open('w3c.html')
content = infile.read()
infile.close()
hp = HeadingParser()
hp.feed(content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-9c9a24610f0b> in <module>
#      49
#      50
# ---> 51 infile = open('w3c.html')
#      52 content = infile.read()
#      53 infile.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'w3c.html'

# %% [markdown]
# ## Question 7
#
# Implement recursive function webdir() that takes as input: a URL (as a string) and
# non-negative integers depth and indent. Your function should visit every web
# page reachable from the starting URL web page in depth clicks or less, and print
# each web page's URL. As shown below, indentation, specified by indent, should
# be used to indicate the depth of a URL.
#
# webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0)
#
# http://reed.cs.depaul.edu/lperkovic/csc242/test1.html
#
# http://reed.cs.depaul.edu/lperkovic/csc242/test2.html
#
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html
#
# http://reed.cs.depaul.edu/lperkovic/csc242/test3.html
#
# http://reed.cs.depaul.edu/lperkovic/csc242/test4.html

# %%
import urllib.request
from html.parser import HTMLParser


class HeadingParser(HTMLParser):
    (h1,h2) = (False, False)
    
    def handle_starttag(self, tag, attrs):
        if tag == 'h1':
            self.h1 = True
        if tag == 'h2':
            self.h2 = True
        if tag == 'h3':
            self.h3 = True
        if tag == 'h4':
            self.h4 = True
        if tag == 'h5':
            self.h5 = True
        if tag == 'h6':
            self.h6 = True
            

    def handle_endtag(self, tag):
        if tag == 'h1':
            self.h1 = False
        if tag == 'h2':
            self.h2 = False
        if tag == 'h3':
            self.h3 = False
        if tag == 'h4':
            self.h4 = False
        if tag == 'h5':
            self.h5 = False
        if tag == 'h6':
            self.h6 = False
            

    def handle_data(self, data):
        if self.h1:
            print(data)
        elif self.h2:
            print("    {}".format(data))
        elif self.h3:
            print("        {}".format(data))
        elif self.h4:
            print("            {}".format(data))
        elif self.h5:
            print("                {}".format(data))
        elif self.h6:
            print("                    {}".format(data))


print(url)
def webdir(url, depth, indent):
    
    if depth == 0:
        return
    
    try: 
        response = urllib.request.urlopen(url)
        html = response.read()

    except urllib.error.URLError:
        return 
    
    # TODO : PARSE URL(S) FROM HTML
    new_url = 
    print("    "*indent + new_url)
    webdir(new_url, depth-1, indent+1)



webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0)
# Out:
#   File "<ipython-input-14-0c44ec9dee63>", line 67
#     new_url =
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Question 8
#
# Write SQL queries on the below database table that return:
#
# a) All the temperature data.
#
# b) All the cities, but without repetition.
#
# c) All the records for India.
#
# d) All the Fall records.
#
# e) The city, country, and season for which the average rainfall is between 200
#     and 400 millimeters.
#
# f) The city and country for which the average Fall temperature is above 20
#    degrees, in increasing temperature order.
#
# g) The total annual rainfall for Cairo.
#
# h) The total rainfall for each season.

# %% [markdown]
# |Desire          | Querry                                                                            |
# | :---              |-----------------:                                                                      |
# | All the Temperature Data | SELECT Temperature FROM rain     |
# | All the Cities, but without repetition     | SELECT DISTINCT city FROM rain   |
# | All the Records for India |    SELECT * FROM rain WHERE Country = 'India'                      |
# | All the Fall Records           | SELECT * FROM rain WHERE Season = 'Fall'     |
# |   the City, Country, and season for which the average rainfall is Between 200 and 400 Millimeters.      | Select city, country, season, AVG(Rainfall) from rain group by city, country, season having avg(rainfall) between 200 and 400;  |
# | The City and Country for which the avrage Fall Temperature is above 20 degrees, in increasing Temperature Order           | Select city, country, AVG(Temperature) as temperature from rain group by city, country having avg(Temperature) >20 order by temperature asc;                  |
# | Total Annual Rainfall for Cairo           | SELECT SUM(Rainfall) FROM rain WHERE City = 'Cairo'                          |
# | Total Rainfall for each season           | Select Season, Sum(Rainfall) from Rain group by Season;                           |

# %% [markdown]
# ## Question 9
#
# Suppose list words is defined as follows:
#
# words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over',
# 'the', 'lazy', 'dog']
#
# Write list comprehension expressions that use list words and generate the following
# lists:
#
# a) ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE',
# 'LAZY', 'DOG']
#
# b) ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog']
#
# c) [3, 5, 5, 3, 5, 4, 3, 4, 3] (the list of lengths of words in list
# words).
#
# d) [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN',
# 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5],
# ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy',
# 4], ['DOG', 'dog', 3]] (the list containing a list for every word of list
# words, where each list contains the word in uppercase and lowercase and the
# length of the word.)
#
# e) ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the',
# 'lazy', 'dog'] (the list of words in list words containing 4 or more
# characters.)

# %%
words = ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']


uppercase_words = [i.upper() for i in words]
lowercase_words = [i.lower() for i in words]
length_words = [len(i) for i in words]
combination_words = [[i.upper(), i.lower(), len(i)] for i in words]
length_more_than_4 = [i for i in words if len(i) >= 4]

print(uppercase_words,"\n\n", lowercase_words,"\n\n", length_words,"\n\n", combination_words,"\n\n", length_more_than_4)
# Out:
# ['THE', 'QUICK', 'BROWN', 'FOX', 'JUMPS', 'OVER', 'THE', 'LAZY', 'DOG']
#
#  ['the', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog']
#
#  [3, 5, 5, 3, 5, 4, 3, 4, 3]
#
#  [['THE', 'the', 3], ['QUICK', 'quick', 5], ['BROWN', 'brown', 5], ['FOX', 'fox', 3], ['JUMPS', 'jumps', 5], ['OVER', 'over', 4], ['THE', 'the', 3], ['LAZY', 'lazy', 4], ['DOG', 'dog', 3]]
#
#  ['quick', 'brown', 'jumps', 'over', 'lazy']
